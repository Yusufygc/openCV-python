# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("C:\\Users\\TUF Dash F15\\Desktop\\cvCourse\\images\\kopek.jpg")

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image
# Out:
# array([[[ 63,  48,  46],
#         [ 60,  45,  42],
#         [ 59,  42,  39],
#         ...,
#         [101, 113, 155],
#         [109, 122, 166],
#         [116, 129, 173]],
#
#        [[ 58,  43,  41],
#         [ 56,  41,  38],
#         [ 55,  39,  33],
#         ...,
#         [115, 126, 164],
#         [119, 132, 170],
#         [125, 138, 176]],
#
#        [[ 50,  38,  34],
#         [ 49,  37,  31],
#         [ 50,  38,  28],
#         ...,
#         [136, 147, 175],
#         [136, 148, 176],
#         [139, 151, 179]],
#
#        ...,
#
#        [[ 74, 152,  81],
#         [ 72, 150,  79],
#         [ 69, 148,  75],
#         ...,
#         [ 87,  24,  93],
#         [ 88,  25,  94],
#         [ 88,  25,  94]],
#
#        [[ 75, 151,  80],
#         [ 72, 150,  79],
#         [ 69, 148,  75],
#         ...,
#         [ 87,  24,  93],
#         [ 87,  24,  93],
#         [ 87,  24,  93]],
#
#        [[ 75, 151,  80],
#         [ 74, 150,  79],
#         [ 69, 148,  75],
# ...

# %%
image.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(image) # matplotlib ile görüntüleme rgb olarak görüntüler

# %%
fix_image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # openCV ile görüntüleme rgb olarak görüntüler

# %%
plt.imshow(fix_image)

# %%
img_gray = cv2.imread("C:\\Users\\TUF Dash F15\\Desktop\\cvCourse\\images\\kopek.jpg", cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (720, 1280)

# %%
img_gray # array olarak görüntüler
# Out:
# array([[ 49,  46,  43, ..., 124, 134, 141],
#        [ 44,  42,  39, ..., 136, 142, 148],
#        [ 38,  37,  36, ..., 154, 155, 158],
#        ...,
#        [122, 120, 117, ...,  52,  53,  53],
#        [121, 120, 117, ...,  52,  52,  52],
#        [121, 120, 117, ...,  51,  52,  52]], dtype=uint8)

# %%
img_gray.max()
# Out:
# 255

# %%
img_gray.min()
# Out:
# 5

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap="gray") # cmap ile gri tonlamalı görüntüleme yapar color map

# %%
plt.imshow(img_gray, cmap="magma")

# %%
plt.imshow(fix_image)

# %%
new_resize =cv2.resize(fix_image, (1000, 400)) # cv2 ile görüntüyü yeniden boyutlandırma 1000 genişlik 400 yükseklik

# %%
plt.imshow(new_resize)

# %%
weight_ratio = 0.5 # genişlik oranı
height_ratio = 0.5 # yükseklik oranı

# %%
new_img = cv2.resize(fix_image, (0,0), fix_image, weight_ratio, height_ratio) # genişlik ve yükseklik oranı ile yeniden boyutlandırma

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (360, 640, 3)

# %%
new_image = cv2.flip(fix_image, -1) # 0 yatay 1 dikey -1 hem yatay hem dikey ÇEVİRME İŞLEMİ

# %%
plt.imshow(new_image)
