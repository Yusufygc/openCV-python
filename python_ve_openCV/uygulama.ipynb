# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("C:\\Users\\TUF Dash F15\\Desktop\\cvCourse\\images\\mete.png")

# %%
cv2.imshow("Mete", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
copy_image = np.copy(rgb_img)

# %%
copy_image=cv2.flip(copy_image, -1) # 0: x eksenine göre yansıtma
plt.imshow(copy_image)

# %%
cv2.rectangle(img,(150,35),(400,265),(0,0,255),3)
cv2.imshow("Mete", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
pts = np.array([[400,300],[300,400],[400,400]], np.int32)
cv2.polylines(img,[pts],True,(0,255,255),3) # cv2.fillPoly() ile içini doldurur
cv2.imshow("Mete", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y),50,(0,255,0),-1)
    elif event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),50,(255,0,0),-1)

cv2.namedWindow(winname='my_drawing')
cv2.setMouseCallback('my_drawing',draw_circle)

while True:
    cv2.imshow('my_drawing',img)
    if cv2.waitKey(20) & 0xFF == 27:
        break

cv2.destroyAllWindows()
